# %%
import numpy as np
import torch
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FFMpegWriter

# %% [markdown]
# # METHOD 1

# %%
def update_line(num, data, line):
    line.set_data(data[..., :num])
    return line,

# %%
fig1 = plt.figure()

# Fixing random state for reproducibility
np.random.seed(19680801)

data = np.random.rand(2, 25)
l, = plt.plot([], [], 'r-')
plt.axis('scaled')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.xlabel('x')
plt.title('test')
line_ani = animation.FuncAnimation(fig1, update_line, 25, fargs=(data, l),
                                   interval=50, blit=True)

# To save the animation, use the command: 
line_ani.save('lines.mp4')
plt.show()

# %% [markdown]
# # METHOD 2

# %%
metadata = dict(title='Behavioral Stereotype', artist='Dong Hur',
                comment='Comment')
writer = FFMpegWriter(fps=15, metadata=metadata)

fig = plt.figure()
l, = plt.plot([], [], 'k-o', linestyle='None')
plt.axis('scaled')
plt.xlim(-5, 5)
plt.ylim(-5, 5)

x0, y0 = 0, 0

with writer.saving(fig, "writer_test.mp4", 100):
    for i in range(100):
        x0_i = 4.9 * np.random.rand()
        y0_i = 4.9 * np.random.rand()
        x0 = np.append(x0, [x0_i])
        y0 = np.append(y0, [y0_i])
        l.set_data(x0, y0)
        writer.grab_frame()
